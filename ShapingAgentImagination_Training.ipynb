# %%
env = 'unity' # deepmindlab

log_path = './log/' + env + '/mem/50k'
exp_name ='exp'
num_actors = 6

queue_maxsize = 25
lu = 100
lo = 32
traj_no_total = 2000
max_update = 1000000
batch_size = 10

rho_bar = 1.
c_bar = 1.
gamma = 0.99
clip_reward = False

grad_clip_norm = 10.
init_lr = 0.0002
epoch = 1000

policy_loss_c = 1.
v_loss_c = 0.5
entropy_c = 0.00015
model_loss_c = 0.1

action_repeat = 6
action_dim = 9
hidden_dim = 512
act_emb_dim = 128
max_frame = 6e4

latent_dim = 16
draw_step = 8

# memory
code_size = 1024
memory_size = 64
dim_s = 128

map_dec_type = 'pixel' # deconv-complex, deconv_simple
mem_type = 'static'

model_save_path = 'model_saved'

kappa = 1e-3

if env == 'unity':
  map_size = [100., 100.]
  pos_dim = (100 // 20)**2 # 5X5 grids
else:
  map_size = [1000., 1000.]
  pos_dim = 1000 // 10
rot_dim = 360 // 18
debug = False

level_cache_dir = '/tmp/level_cache'

# %%
import torch
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # utils

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

# In[ ]:


class ResidualBlock(nn.Module):
    
    def __init__(self, in_channels, hid_channels, out_channels,
                 kernel_size_1, stride_1, padding_1,
                 kernel_size_2, stride_2, padding_2):
        super().__init__()
        
        self.main = nn.Sequential(
            Conv2dBlock(in_channels, hid_channels, kernel_size_1, stride_1, padding_1),
            Conv2dBlock(hid_channels, out_channels, kernel_size_2, stride_2, padding_2))
        
        self.skip = Conv2dBlock(in_channels, out_channels, kernel_size_2, stride_2, padding_2)
    
    
    def forward(self, x):
        
        return self.main(x) + self.skip(x)


# In[22]:


class Conv2dBlock(nn.Module):
    
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0):
        super().__init__()
        
        self.m = conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
        self.weight = nn.Parameter(torch.ones(out_channels))
        self.bias = nn.Parameter(torch.zeros(out_channels))
    
    
    def forward(self, x):
        
        x = self.m(x)
        return F.relu(F.group_norm(x, 8, self.weight, self.bias))


# In[ ]:


def conv2d(in_channels, out_channels, kernel_size, stride=1,
           padding=0, dilation=1, groups=1,
           bias=True, padding_mode='zeros',
           weight_init='kaiming'):
    
    m = nn.Conv2d(in_channels, out_channels, kernel_size, stride,
                  padding, dilation, groups, bias, padding_mode)
    
    if weight_init == 'xavier':
        nn.init.xavier_normal_(m.weight)
    else:
        nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
    
    if bias:
        nn.init.zeros_(m.bias)
    
    return m


# In[ ]:


class GaussianWithConv2d(nn.Module):
    
    def __init__(self, c_in, c_out):
        super(GaussianWithConv2d, self).__init__()
        
        self.enc = conv2d(c_in, 2 * c_out, 5, 1, 2, weight_init='xavier')
    
    
    def forward(self, inputs):
        # type: (Tensor) -> Tuple[Tensor, Tensor]
        mu, std = self.enc(inputs).chunk(2, 1)
        std = F.softplus(std) + 1e-5
        return mu, std


# In[13]:


class GatedCNN(nn.Module):
  
  def __init__(self, input_size, hidden_size):
    super().__init__()
    
    self.conv_h = nn.Conv2d(input_size, hidden_size*2, 5, 1, 2)
    # self.conv_h = nn.Conv2d(64, hidden_size*2, 3, 1, 1)
    
  def forward(self, h, x):
    
    h = self.conv_h(torch.cat([x, h], dim=1))
    # h = self.conv_h(x + h)
    
    h1, h2 = torch.chunk(h, 2, dim=1)
    h = torch.tanh(h1) * torch.sigmoid(h2)
    
    return h
    
class AgentCoreBaseVisEncoder(nn.Module):
  def __init__(self, c_in, c_out):
    super().__init__()

    self.conv = nn.Conv2d(c_in, c_out, 3, 1, 1)
    self.pad = nn.ZeroPad2d((0, 1, 0, 1))
    self.max_pool = nn.MaxPool2d(3, 2)
    self.residual = ResidualBlock(c_out, c_out, c_out, 3, 1, 1, 3, 1, 1)

    self.net = nn.Sequential(self.pad, self.conv, self.max_pool, self.residual)

  def forward(self, x):
    return self.net(x)

class AgentCoreDeepVisEncoder(nn.Module):
  def __init__(self):
    super().__init__()

    self.block_1 = AgentCoreBaseVisEncoder(3, 16)
    self.block_2 = AgentCoreBaseVisEncoder(16, 32)
    self.block_3 = AgentCoreBaseVisEncoder(32, 32)
    
    self.fc = nn.Linear(8*8*32, 256)

    self.net = nn.Sequential(self.block_1, self.block_2, self.block_3, nn.Flatten(), nn.ReLU(), self.fc, nn.ReLU())

  def forward(self, x):
    return self.net(x)

def weight_init(m): 
  if isinstance(m, nn.Linear):
    init.normal_(m.weight, std=0.04)

# %% [markdown]
# # modules_unity

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
# from utils import *
from torch.distributions import Categorical
import pdb


# In[ ]:
# device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")

class Policy(nn.Module):
  
  def __init__(self):
    
    super().__init__()
    self.visual_enc = AgentCoreDeepVisEncoder().to(device)
    
    self.agent_core = nn.LSTM(256+act_emb_dim, hidden_dim, batch_first=True).to(device)
    
    
  def init_state(self, B):
    h0 = torch.zeros(1, B, hidden_dim, device=device)
    c0 = torch.zeros(1, B, hidden_dim, device=device)

    return h0, c0

  def forward(self, x, act):

    B, T, C, H, W = x.shape

    x_t_enc = self.visual_enc(x.reshape(B*T, C, H, W)).reshape(B, T, -1)

    x_t_act = torch.cat([x_t_enc, act], dim=-1)

    states_h = []
    states_c = []

    h, c = self.init_state(B) # 1, B, H
    states_h.append(h)
    states_c.append(c)

    for t in range(T):

      o, (h, c) = self.agent_core(x_t_act[:, t:t+1], (h, c))
      
      states_h.append(h)
      states_c.append(c)

    states_h = torch.cat(states_h, dim=0).permute(1,0,2) # B, T+1, H
    states_c = torch.cat(states_c, dim=0).permute(1,0,2)

    return states_h, states_c

# In[ ]:


class MapDecoder(nn.Module):
  
  def __init__(self):
    
    super().__init__()
    
    #TODO
 
    if map_dec_type == 'pixel':
      self.dec = nn.Sequential(
        Conv2dBlock(hidden_dim*2, 256*4*4, 1, 1, 0),
        nn.PixelShuffle(4),
        Conv2dBlock(256, 128*4*4, 3, 1, 1),
        nn.PixelShuffle(4),
        Conv2dBlock(128, 64*4*4, 3, 1, 1),
        nn.PixelShuffle(4),
        nn.Conv2d(64, 3, 3, 1, 1),
        nn.Sigmoid()
      ).to(device)
    elif map_dec_type == 'deconv-complex':
      self.dec = nn.Sequential(
          nn.ConvTranspose2d(hidden_dim*2, 256, 4, 4),
          nn.GroupNorm(32, 256),
          nn.ReLU(),
          nn.ConvTranspose2d(256, 128, 4, 4),
          nn.GroupNorm(16, 128),
          nn.ReLU(),
          nn.ConvTranspose2d(128, 64, 4, 4),
          nn.GroupNorm(8, 64),
          nn.ReLU(),
          nn.Conv2d(64, 3, 3, 1, 1)
        ).to(device)
    elif map_dec_type == 'deconv-simple':
      self.dec = nn.Sequential(
          nn.ConvTranspose2d(hidden_dim*2, 64, 4, 4),
          nn.GroupNorm(8, 64),
          nn.ReLU(),
          nn.ConvTranspose2d(64, 32, 4, 4),
          nn.GroupNorm(4, 32),
          nn.ReLU(),
          nn.ConvTranspose2d(32, 16, 4, 4),
          nn.GroupNorm(2, 16),
          nn.ReLU(),
          nn.Conv2d(16, 3, 3, 1, 1)
        ).to(device)
    

  def forward(self, h, map_gt):
    map_pred = self.dec(h.unsqueeze(-1).unsqueeze(-1))
    loss = ((map_pred - map_gt).pow(2).sum(dim=(1,2,3))).mean()
    return map_pred, loss


# In[ ]:


class PositionDecoder(nn.Module):
  
  def __init__(self):
    
    super().__init__()
    
    self.dec = nn.Sequential(
      nn.Linear(hidden_dim*2, pos_dim),
    ).to(device)
    
  def forward(self, h, pos_gt):
    pos_gt_ = pos_gt + 50 # [-50, 50] --> [0, 100]
    pos_gt_ = pos_gt_ // 20 # 5x5 grid
    pos_cls_gt = pos_gt_[:, 0]*5 + pos_gt_[:, 1] # 0~25
    pos_pred = self.dec(h)
    pos_acc = ((pos_pred.argmax(dim=1)).long() == (pos_cls_gt).long()).float().mean()
    loss = F.cross_entropy(pos_pred, pos_cls_gt.long(), reduction='none')
    loss = loss.mean()
    return pos_acc, loss

class RotDecoder(nn.Module):
  
  def __init__(self):
    
    super().__init__()
    
    self.dec = nn.Sequential(
      nn.Linear(hidden_dim*2, rot_dim),
    ).to(device)
    
  def forward(self, h, rot_gt):
    rot_gt_ = (rot_gt % 360.) // 18 # 20 cls
    rot_pred = self.dec(h)
    rot_acc = ((rot_pred.argmax(dim=1)).long() == (rot_gt_).long()).float().mean()

    loss = F.cross_entropy(rot_pred, rot_gt_.long(), reduction='none')
    loss = loss.mean()
    return rot_acc, loss

# In[80]:


class ConvDraw(nn.Module):
  
  def __init__(self):
    
    super().__init__()
    
    self.img_enc = nn.Sequential(
      Conv2dBlock(3*2, 16, 4, 2, 1),
      Conv2dBlock(16, 16, 4, 2, 1),
      Conv2dBlock(16, 64, 4, 2, 1),
    ).to(device)
    
    self.img_dec = nn.Sequential(
      Conv2dBlock(64, 32*2*2, 3, 1, 1),
      nn.PixelShuffle(2),
      Conv2dBlock(32, 32*2*2, 3, 1, 1),
      nn.PixelShuffle(2),
      nn.Conv2d(32, 3*2*2, 3, 1, 1),
      nn.PixelShuffle(2),
    ).to(device)
    
    self.sim_core_enc = nn.Sequential(
      nn.ConvTranspose2d(hidden_dim, 256, 4, 2, 1),
      nn.GroupNorm(32, 256),
      nn.ReLU(),
      nn.ConvTranspose2d(256, 128, 4, 2, 1),
      nn.GroupNorm(16, 128),
      nn.ReLU(),
      nn.ConvTranspose2d(128, 64, 4, 2, 1),
      nn.GroupNorm(8, 64),
      nn.ReLU(),
    ).to(device)
    
    self.num_steps = draw_step

    self.decoder = nn.ModuleList([GatedCNN(64+latent_dim, 64).to(device) for _ in range(self.num_steps)])
    self.posterior = nn.ModuleList([GatedCNN(64*2, 64).to(device) for _ in range(self.num_steps)])
    self.prior = nn.ModuleList([GatedCNN(64*2, 64).to(device) for _ in range(self.num_steps)])
    
    self.gaussian_p = GaussianWithConv2d(64, latent_dim).to(device)
    self.gaussian_q = GaussianWithConv2d(64, latent_dim).to(device)

    
    
    
  def init_states(self, B):
    
    h_p = torch.zeros(B, 64, 8, 8, device=device, dtype=torch.float)
    h_q = torch.zeros(B, 64, 8, 8, device=device, dtype=torch.float)
    h_rec = torch.zeros(B, 64, 8, 8, device=device, dtype=torch.float)
    
    return h_p, h_q, h_rec
  
  def forward(self, sim_core_h, x_t, is_training=True):
    
    B = x_t.shape[0]
    
    h_p, h_q, h_rec = self.init_states(B)
    
    sim_core_h = sim_core_h.unsqueeze(-1).unsqueeze(-1)
    sim_core_h_enc = self.sim_core_enc(sim_core_h)
    
    rec_err = x_t.new_zeros(x_t.shape)
    rec_x = x_t.new_zeros(x_t.shape)
    
    kl_loss = 0.
    
    for i in range(self.num_steps):
      
      if i == 0:
        for _ in range(4):
          h_p = self.prior[i](h_p, sim_core_h_enc)
      else:
        h_p = self.prior[i](h_p, sim_core_h_enc)
      
      # x_t_enc = self.img_enc(x_t)
      
      if is_training:
        rec_err_enc = self.img_enc(torch.cat([x_t, rec_err], dim=1))
        h_q = self.posterior[i](h_q, rec_err_enc)
        
        mu_q, std_q = self.gaussian_q(h_q)
        mu_p, std_p = self.gaussian_p(h_p)
        z = self.sample(mu_q, std_q)
        kl_loss = kl_loss + self.cal_kl(mu_p, std_p, mu_q, std_q)
        
        h_rec = self.decoder[i](h_rec, z)
        x_hat = self.img_dec(h_rec)
        rec_x = rec_x + x_hat
        rec_err = x_t - rec_x

      else:
        
        mu_p, std_p = self.gaussian_p(h_p)
        z = self.sample(mu_p, std_p)
      
        h_rec = self.decoder[i](h_rec, z)
        x_hat = self.img_dec(h_rec)
        rec_x = rec_x + x_hat

      rec_x = rec_x.sigmoid()

    if is_training:

      constraint = self.constraint(x_t, rec_x)
      return rec_x, constraint.mean(), kl_loss.sum(dim=(1,2,3)).mean()

    else:
      return rec_x
        
  def constraint(self, x, rec):
    # kappa is pixel space error threshold
    return torch.sum(torch.pow(rec - x, 2), dim = (1,2,3)) - kappa * 64 * 64 * 3

  def sample(self, mu, std):
    
    noise = torch.empty_like(mu).normal_()
    
    return mu + std * noise
  
  def cal_kl(self, mu_p, std_p, mu_q, std_q):
    
    var_ratio = (std_q / std_p) ** 2
    
    return 0.5 * (((mu_q - mu_p) / std_p) ** 2 + (var_ratio - 1) - var_ratio.log())

# %% [markdown]
# # Logger

# %%
from torch.utils.tensorboard import SummaryWriter
from enum import Enum
from threading import Thread
from queue import Empty


class SummaryType(Enum):
    SCALAR = 1
    HISTOGRAM = 2
    VIDEO = 3
    IMAGE = 4
    FIGURE = 5
    GRAPH = 6


# Not working asynchronously
class Statistics(Thread):
    """Writes the statistics of the async processes into a tensorboard"""

    def __init__(self, writer_dir, statistics_queue, nb_episodes):

        super(Statistics, self).__init__()

        self.exit = False

        self.stats_queue = statistics_queue
        self.nb_episodes = nb_episodes

        self._writer = SummaryWriter(log_dir=writer_dir)

    def run(self):

        super(Statistics, self).run()

        # Make sure that all the logs are pushed to the tensorboard
        last_step = 0
        while True:

            try:
                summary_type, tag, data = self.stats_queue.get(timeout=1)
            except Empty:
                if self.exit:
                    break
                continue

            # Push the informations
            step = self.nb_episodes.value

            frames = step * 100

            if summary_type == summary_type.SCALAR:
                self._writer.add_scalar(tag=tag, scalar_value=data, global_step=frames)

            elif summary_type == summary_type.HISTOGRAM:
                self._writer.add_histogram(
                    tag=tag, values=data, global_step=frames, bins="tensorflow"
                )

            elif summary_type == summary_type.FIGURE:
                self._writer.add_figure(tag=tag, figure=frames, global_step=step)

            elif summary_type == summary_type.IMAGE:
                if data.dim() > 3:
                    self._writer.add_images(
                        tag=tag, img_tensor=data, global_step=frames, dataformats="NCHW"
                    )
                else:
                    self._writer.add_image(
                        tag=tag, img_tensor=data, global_step=frames, dataformats="CHW"
                    )

            elif summary_type == summary_type.VIDEO:
                self._writer.add_video(tag=tag, vid_tensor=data, global_step=frames, fps=4)

            elif summary_type == summary_type.GRAPH:
                self._writer.add_graph(model=data)

        self._writer.close()

# %% [markdown]
# # Learner_StoredData

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.utils as vutils
# from modules_unity import *
from torch.utils.tensorboard import SummaryWriter
import time
# from env_utils import MetricLogger, plot_traj_step
import os
import pickle
import pdb

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float

class Learner(object):

  def __init__(
    self,
    id,
    policy,
    train_dl,
    val_dl,
    
    timeout=200
  ):

    self.id = id
    self.policy = policy

    # todo: learning rate

    self.timeout = timeout

    
    self.train_dl = train_dl
    self.val_dl = val_dl

    self.map_decoder = MapDecoder()
    self.pos_decoder = PositionDecoder()
    self.rot_decoder = RotDecoder()
    self.conv_draw = ConvDraw()
    self.sim_core = nn.LSTMCell(act_emb_dim, hidden_dim).to(device)
    self.action_emb_layer = nn.Embedding(6, act_emb_dim).to(device)

    self.params = [*self.policy.parameters(),
      *self.map_decoder.parameters(), *self.pos_decoder.parameters(), *self.rot_decoder.parameters(),
      *self.conv_draw.parameters(), *self.sim_core.parameters(), *self.action_emb_layer.parameters()]

    # self.params = [*self.policy.parameters()]

    self.optimizer = torch.optim.Adam(
      self.params, lr=init_lr, betas=(0, 0.999), eps=3.125e-7
    )
    # self.scheduler = torch.optim.lr_scheduler.LambdaLR(self.optimizer, lambda epoch: 0.95)
    self.timer = MetricLogger()

#     exp_name = exp_name + '-lr{}-h{}-kappa{}-zdim{}-mapdec_{}-maxf{}'.format(init_lr,
#                                                           hidden_dim,
#                                                           kappa,
#                                                           latent_dim, map_dec_type, max_frame)
#     log_path = os.path.join(log_path, exp_name)
    self.writer = SummaryWriter(log_dir=log_path)

    self.model_save_path = os.path.join(log_path, model_save_path)
    if not os.path.exists(self.model_save_path):
      os.makedirs(self.model_save_path)

    self.model_file_list = os.path.join(self.model_save_path, 'model_list.pkl')
    if not os.path.exists(self.model_file_list):
      with open(self.model_file_list, 'wb') as f:
        model_list = []
        pickle.dump(model_list, f)

  def run(self):
    self.lambd = torch.empty(1, device=device).fill_(1000.)

    self.best_loss = 1000000.

    train_dl = self.train_dl
    val_dl = self.val_dl
    for e in range(epoch):
      self.learn(e, train_dl)
      self.generate(e, val_dl)


  def enable_eval(self):

    self.policy.eval()
    self.map_decoder.eval()
    self.pos_decoder.eval()
    self.rot_decoder.eval()
    self.conv_draw.eval()
    self.sim_core.eval()
    self.action_emb_layer.eval()

  def enable_training(self):

    self.policy.train()
    self.map_decoder.train()
    self.pos_decoder.train()
    self.rot_decoder.train()
    self.conv_draw.train()
    self.sim_core.train()
    self.action_emb_layer.train()

  def visual_test(self, traj):

    self.enable_eval()

    with torch.no_grad():

      agent_view = traj['agent_view'].to(device) # B, T, C, H, W
      map_top_down = traj['map_top_down'].to(device) # B, T, C, H, W
      actions = traj['actions'].to(device) # B, T, 1
      pos = traj['pos'].to(device) # B, T, 2
      rot = traj['rot'].to(device) # B, T

      B, T, C, H, W = map_top_down.shape

      action_0 = actions.new_zeros(B, 1, 1)
      actions = torch.cat([action_0, actions[:, :-1]], dim=1) # B, T+1, 1
      act_emb = self.action_emb_layer(actions.long()).reshape(B, T, act_emb_dim)

      state_h, state_c = self.policy(agent_view, act_emb) # B, T+1, H

      us = torch.cat([state_h[:, 1:-1], state_c[:, 1:-1].tanh()], dim=-1)
      map_pred, map_loss = self.map_decoder(us.reshape(B*(T-1), -1).detach(),
                                            map_top_down[:, :-1].reshape(B*(T-1), C, H, W))

      pos_acc, pos_loss = self.pos_decoder(us.reshape(B*(T-1), -1).detach(), pos[:,:-1].reshape(B*(T-1), -1))
      rot_acc, rot_loss = self.rot_decoder(us.reshape(B*(T-1), -1).detach(), rot[:,:-1].reshape(B*(T-1)))

      agent_view_rec, agent_view_gen, agent_view_gt, constraint, kl_loss, agent_mse = self.sim_core_rollout((state_h,state_c), act_emb.reshape(B, T, -1), agent_view, is_training=False)

      seq_gt, seq_gen, gen_mse = self.sim_core_rollout_seq((state_h,state_c), act_emb.reshape(B, T, -1), agent_view, t_i=50)
      rollout_t = seq_gt.shape[1]

    map_traj_batch = []
    for i in range(B):
      map_traj = plot_traj_step(map_top_down[i, 0].permute(1,2,0).cpu().numpy(), pos[i].cpu().numpy())
      map_traj = torch.tensor(map_traj).float().permute(0, 3, 1, 2)
      map_traj_batch.append(map_traj)

    map_traj_batch = torch.stack(map_traj_batch, dim=0)

    return map_traj_batch, map_pred.reshape(B, T-1, C, H, W), seq_gen, agent_view


  def generate(self, e, val_dl):

    val_log = dict(
      map_loss_total = 0.,
      pos_loss_total = 0.,
      rot_loss_total = 0.,
      kl_loss_total = 0.,
      model_loss_total = 0.,
      pos_acc_total = 0.,
      rot_acc_total = 0.,
      gen_mse_total = 0.,
    )

    self.enable_eval()

    with torch.no_grad():

      for i, traj in enumerate(val_dl):

        agent_view = traj['agent_view'].to(device) # B, T, C, H, W
        map_top_down = traj['map_top_down'].to(device) # B, T, C, H, W
        actions = traj['actions'].to(device) # B, T, 1
        pos = traj['pos'].to(device) # B, T, 2
        rot = traj['rot'].to(device) # B, T

        B, T, C, H, W = map_top_down.shape

        action_0 = actions.new_zeros(B, 1, 1)
        actions = torch.cat([action_0, actions[:, :-1]], dim=1) # B, T+1, 1
        act_emb = self.action_emb_layer(actions.long()).reshape(B, T, act_emb_dim)

        state_h, state_c = self.policy(agent_view, act_emb) # B, T+1, H

        us = torch.cat([state_h[:, 1:-1], state_c[:, 1:-1].tanh()], dim=-1)
        map_pred, map_loss = self.map_decoder(us.reshape(B*(T-1), -1).detach(),
                                              map_top_down[:, :-1].reshape(B*(T-1), C, H, W))

        pos_acc, pos_loss = self.pos_decoder(us.reshape(B*(T-1), -1).detach(), pos[:,:-1].reshape(B*(T-1), -1))
        rot_acc, rot_loss = self.rot_decoder(us.reshape(B*(T-1), -1).detach(), rot[:,:-1].reshape(B*(T-1)))

        agent_view_rec, agent_view_gen, agent_view_gt, constraint, kl_loss, agent_mse = self.sim_core_rollout((state_h,state_c), act_emb.reshape(B, T, -1), agent_view, is_training=False)

        seq_gt, seq_gen, gen_mse = self.sim_core_rollout_seq((state_h,state_c), act_emb.reshape(B, T, -1), agent_view)
        rollout_t = seq_gt.shape[1]

        model_loss = kl_loss + self.lambd * constraint

        val_log['map_loss_total'] += map_loss
        val_log['pos_loss_total'] += pos_loss
        val_log['rot_loss_total'] += rot_loss
        val_log['kl_loss_total'] += kl_loss
        val_log['model_loss_total'] += model_loss
        val_log['pos_acc_total'] += pos_acc
        val_log['rot_acc_total'] += rot_acc
        val_log['gen_mse_total'] += gen_mse

      map_traj = plot_traj_step(map_top_down[0, 0].permute(1,2,0).cpu().numpy(), pos[0].cpu().numpy())
      map_traj = torch.tensor(map_traj).float().permute(0, 3, 1, 2)

    self.writer.add_image("Validation/map_dec",
        vutils.make_grid(torch.cat([map_traj.reshape(T, C, H, W)[:-1],
                                    map_pred.detach().cpu().reshape(B, T-1, C, H, W)[0]], dim=0), nrow=100),
        e)

    self.writer.add_image("Validation/rollout_agent_views",
        vutils.make_grid(torch.cat([seq_gt[0], seq_gen.detach()[0]], dim=0), nrow=rollout_t),
        e)

    total_loss = 0.
    for n, l in val_log.items():
      self.writer.add_scalar("Validation/" + n, l / len(val_dl), e)
      total_loss += l.item()

    total_loss = total_loss / len(val_dl)

    if total_loss < self.best_loss:
      filename = os.path.join(self.model_save_path, 'best_model.pth')
      self.save(e, filename=filename)
      self.best_loss = total_loss

    self.save(e)

  def learn(self, e, train_dl):

    self.enable_training()

    for i, traj in enumerate(train_dl):

      self.update_count = e * len(train_dl) + i

      map_loss = 0.
      pos_loss = 0.
      model_loss = 0.

      traj_batch = []
      start = time.time()
      
      agent_view = traj['agent_view'].to(device) # B, T, C, H, W
      map_top_down = traj['map_top_down'].to(device) # B, T, C, H, W
      actions = traj['actions'].to(device) # B, T, 1
      pos = traj['pos'].to(device) # B, T, 2
      rot = traj['rot'].to(device) # B, T
      B, T, C, H, W = map_top_down.shape

      action_0 = actions.new_zeros(B, 1, 1)
      actions = torch.cat([action_0, actions[:, :-1]], dim=1) # B, T+1, 1
      act_emb = self.action_emb_layer(actions.long()).reshape(B, T, act_emb_dim)

      end = time.time()
      data_proc_time = end - start
      self.timer['data_proc_time'] = data_proc_time
      start = end

      state_h, state_c = self.policy(agent_view, act_emb) # B, T+1, H

      end = time.time()
      agent_core_time = end - start
      self.timer['agent_core_time'] = agent_core_time
      start = end

      us = torch.cat([state_h[:, 1:-1], state_c[:, 1:-1].tanh()], dim=-1)
      map_pred, map_loss = self.map_decoder(us.detach().reshape(B*(T-1), -1),
                                            map_top_down[:, :-1].reshape(B*(T-1), C, H, W))

      pos_acc, pos_loss = self.pos_decoder(us.detach().reshape(B*(T-1), -1), pos[:,:-1].reshape(B*(T-1), -1))
      rot_acc, rot_loss = self.rot_decoder(us.detach().reshape(B*(T-1), -1), rot[:,:-1].reshape(B*(T-1)))

      end = time.time()
      loss_time = end - start
      self.timer['pos_map_time'] = loss_time
      start = end

      if self.update_count % 100 == 0:

        agent_view_rec, agent_view_gen, agent_view_gt, constraint, kl_loss, agent_mse = self.sim_core_rollout((state_h,state_c), act_emb.reshape(B, T, -1), agent_view, is_training=False)

      else:

        agent_view_rec, agent_view_gt, constraint, kl_loss, agent_mse = self.sim_core_rollout((state_h,state_c), act_emb.reshape(B, T, -1), agent_view)

      model_loss = kl_loss + self.lambd * constraint

      with torch.no_grad():
        if self.update_count == 0:
          self.constrain_ma = constraint.clone()
        else:
          self.constrain_ma = 0.99 * self.constrain_ma.detach_() + (1 - 0.99) * constraint

        if self.update_count % 100 == 0:
          self.lambd = self.lambd * torch.clamp(torch.exp(self.constrain_ma), 0.9, 1.1)
          self.lambd = torch.clamp(self.lambd, 0., 1000.)

      end = time.time()
      loss_time = end - start
      self.timer['conv_draw_time'] = loss_time
      start = end

      total_loss = model_loss + map_loss + pos_loss + rot_loss

      self.optimizer.zero_grad()
      total_loss.backward()

      torch.nn.utils.clip_grad_norm_(self.params, grad_clip_norm)

      end = time.time()
      backward_time = end - start
      self.timer['backward_time'] = backward_time
      start = end

      if self.update_count % 500 == 0:
        self.log_grad()

      self.optimizer.step()
      #TODO fix lr scheduler
      lr = poly_lr_scheduler(self.optimizer, init_lr, self.update_count, max_frame)

      end = time.time()
      step_time = end - start
      self.timer['step_time'] = step_time
      start = end

      if self.update_count % 100 == 0:
        losses = dict(
          map_dec_loss = map_loss.detach().item(),
          position_loss = pos_loss.detach().item(),
          rot_loss = rot_loss.detach().item(),
          kl_loss = kl_loss.detach().item(),
          overshoot_loss = constraint.detach().item(),
          model_loss = model_loss.detach().item(),
          total_loss = total_loss.detach().item()
        )
        self.log_loss(losses)

        self.writer.add_scalar("learner/lr", lr, self.update_count)
        self.writer.add_scalar("geco/geco-lambda", self.lambd, self.update_count)
        self.writer.add_scalar("geco/geco-rec-mse", agent_mse.item(), self.update_count)
        self.writer.add_scalar("prediction/pos/batch_rot_acc", rot_acc, self.update_count)
        self.writer.add_scalar("prediction/pos/batch_pos_acc", pos_acc, self.update_count)

        # self.logger_q.put(
        #   ( SummaryType.VIDEO, 
        #     "learner/agent_views/agent_views",
        #     agent_view[:1])
        # )
        # self.logger_q.put(
        #   ( SummaryType.VIDEO, 
        #     "learner/agent_views/map_top_down",
        #     map_top_down[:1])
        # )

        self.writer.add_image("learner/map_dec",
            vutils.make_grid(torch.cat([map_top_down.reshape(B, T, C, H, W)[0, 50:-1],
                                        map_pred.detach().reshape(B, T-1, C, H, W)[0, 50:]], dim=0), nrow=50),
            self.update_count)

        self.writer.add_image("learner/overshooting/agent_views",
            vutils.make_grid(torch.cat([agent_view_gt[:6], agent_view_rec.detach()[:6], agent_view_gen.detach()[:6]], dim=0), nrow=6),
            self.update_count)

        self.writer.flush()

        print("=========== Losses ===========\n")
        for n, l in losses.items():
          print("{}:\t\t {:.6f}".format(n, l))

        print("=========== Timer Measure ===========\n")
        for key in self.timer.values:
          print("{}:\t\t {:.6f}".format(key, self.timer[key].avg))

  def log_grad(self):

    for tag, parm in self.policy.named_parameters():
      self.writer.add_scalar("gradient/policy/" + tag, parm.grad.data.norm(2), self.update_count)

    for tag, parm in self.sim_core.named_parameters():
      self.writer.add_scalar("gradient/sim_core/" + tag, parm.grad.data.norm(2), self.update_count)

    for tag, parm in self.conv_draw.named_parameters():
      self.writer.add_scalar("gradient/conv_draw/" + tag, parm.grad.data.norm(2), self.update_count)

    for tag, parm in self.pos_decoder.named_parameters():
      self.writer.add_scalar("gradient/pos_dec/" + tag, parm.grad.data.norm(2), self.update_count)

    for tag, parm in self.rot_decoder.named_parameters():
      self.writer.add_scalar("gradient/rot_dec/" + tag, parm.grad.data.norm(2), self.update_count)

    for tag, parm in self.map_decoder.named_parameters():
      self.writer.add_scalar("gradient/map_decoder/" + tag, parm.grad.data.norm(2), self.update_count)

  def log_loss(self, losses):

    for n, l in losses.items():
      self.writer.add_scalar("loss/"+n, l, self.update_count)

  def sim_core_rollout_seq(self, bt, actions, agent_view, t_i=None):
    B, T, C, H, W = agent_view.shape
    # sample starting point for trajectories
    if t_i == None:
      t_i = torch.randint(1, lu, (1, ), device=device)
    else:
      t_i = torch.tensor([t_i]).to(device)

    rollout_t = lu - t_i

    h, c = bt
    bt = h[:, t_i]
    bct = c[:, t_i]
    h_sim, c_sim = bt.reshape(B, hidden_dim), bct.reshape(B, hidden_dim)

    h_sim_list = []

    for j in range(rollout_t):
      h_sim, c_sim = self.sim_core(actions[:, t_i+j].reshape(B, act_emb_dim).float(), (h_sim, c_sim))
      h_sim_list.append(h_sim.reshape(B, hidden_dim))

    h_sim = torch.stack(h_sim_list, dim=1).reshape(B*rollout_t, hidden_dim) # B, t, h

    agent_view_gt = agent_view[:, t_i[0]:t_i[0]+rollout_t].reshape(B*rollout_t, C, H, W) # B, t, C, H, W, shift one step

    agent_view_gen = self.conv_draw(h_sim, agent_view_gt, is_training=False)

    with torch.no_grad():
      gen_mse = (agent_view_gen - agent_view_gt).pow(2).sum(dim=(1,2,3)).mean()

    return agent_view_gt.reshape(B, rollout_t, C, H, W), agent_view_gen.reshape(B, rollout_t, C, H, W), gen_mse

  def sim_core_rollout(self, bt, actions, agent_view, is_training=True):

    B, T, C, H, W = agent_view.shape
    # sample starting point for trajectories
    t_i = torch.randint(1, lu, (2, ), device=device)

    # sample points to eval likelihood
    delta_k_i_list = []
    for tt in t_i:
      delta_k_i = torch.randint(1, min(lu-tt+1, lo+1), (6, ), device=device)
      delta_k_i_list.append(delta_k_i)

    rollout_t = torch.stack(delta_k_i_list).max()

    h, c = bt
    bt = h[:, t_i]
    bct = c[:, t_i]
    h_sim, c_sim = bt.reshape(B*2, hidden_dim), bct.reshape(B*2, hidden_dim)

    h_sim_list_1 = []
    h_sim_list_2 = []

    action_sim = self.pad_actions(actions, t_i, rollout_t)

    for j in range(rollout_t):
      h_sim, c_sim = self.sim_core(action_sim[:, t_i+j].reshape(B*2, act_emb_dim).float(), (h_sim, c_sim))
      h1, h2 = h_sim.reshape(B, 2, hidden_dim).chunk(2, dim=1)
      h_sim_list_1.append(h1.reshape(B, hidden_dim))
      h_sim_list_2.append(h2.reshape(B, hidden_dim))

    h_sim_1 = torch.stack(h_sim_list_1, dim=1)[:, delta_k_i_list[0] - 1] # B, 6, h
    h_sim_2 = torch.stack(h_sim_list_2, dim=1)[:, delta_k_i_list[1] - 1]

    agent_view_1 = agent_view[:, t_i[0]:t_i[0]+rollout_t][:, delta_k_i_list[0]-1] # B, 6, C, H, W, shift one step
    agent_view_2 = agent_view[:, t_i[1]:t_i[1]+rollout_t][:, delta_k_i_list[1]-1]


    h_sim = torch.cat([h_sim_1, h_sim_2], dim=1).reshape(B*6*2, hidden_dim)
    agent_view_gt = torch.cat([agent_view_1, agent_view_2], dim=1).reshape(B*6*2, C, H, W)

    agent_view_rec, constraint, kl_loss = self.conv_draw(h_sim, agent_view_gt, is_training=True)

    with torch.no_grad():
      rec_mse = (agent_view_rec - agent_view_gt).pow(2).sum(dim=(1,2,3)).mean()

    if not is_training:

      with torch.no_grad():
        agent_view_gen = self.conv_draw(h_sim, agent_view_gt, is_training=False)

      return agent_view_rec, agent_view_gen, agent_view_gt, constraint, kl_loss, rec_mse

    else:
      return agent_view_rec, agent_view_gt, constraint, kl_loss, rec_mse

  def pad_actions(self, action, start_t, rollout_len):
    pad_len = (start_t + rollout_len).max() - 5
    if pad_len > 0:
      action_pad = action.new_zeros(action.shape[0], pad_len, act_emb_dim)
      action = torch.cat([action, action_pad], dim=1)

    return action

  def load(self, path):
    """ Load model parameters """
    checkpoint = torch.load(path)
    self.policy.load_state_dict(checkpoint["policy"])
    self.sim_core.load_state_dict(checkpoint["sim_core"])
    self.conv_draw.load_state_dict(checkpoint["conv_draw"])
    self.pos_decoder.load_state_dict(checkpoint["pos_decoder"])
    self.rot_decoder.load_state_dict(checkpoint["rot_decoder"])
    self.map_decoder.load_state_dict(checkpoint["map_decoder"])
    self.action_emb_layer.load_state_dict(checkpoint["action_emb_layer"])
    global_step = checkpoint['global_step']

  def save(self, global_step, maxnum=3, filename=None):
    if filename is None:
      filename = os.path.join(self.model_save_path, 'model_{:09}.pth'.format(global_step+1))

      with open(self.model_file_list, 'rb+') as f:
        model_list = pickle.load(f)
        if len(model_list) >= maxnum:
          if os.path.exists(model_list[0]):
            os.remove(model_list[0])
          del model_list[0]
        model_list.append(filename)
      with open(self.model_file_list, 'rb+') as f:
        pickle.dump(model_list, f)

    torch.save(
        {
            "policy": self.policy.state_dict(),
            "map_decoder": self.map_decoder.state_dict(),
            "rot_decoder": self.rot_decoder.state_dict(),
            "pos_decoder": self.pos_decoder.state_dict(),
            "conv_draw": self.conv_draw.state_dict(),
            "sim_core": self.sim_core.state_dict(),
            "action_emb_layer": self.action_emb_layer.state_dict(),
            "global_step": global_step,
        },
        filename,
    )
    print("save model to {}".format(filename))


def poly_lr_scheduler(optimizer, init_lr, num_frame, max_frame, lr_decay_iter=1,
                      power=1.):
  """Polynomial decay of learning rate
    :param init_lr is base learning rate
    :param iter is a current iteration
    :param lr_decay_iter how frequently decay occurs, default is 1
    :param max_iter is number of maximum iterations
    :param power is a polymomial power

  """
  if num_frame % lr_decay_iter or num_frame > max_frame:
    return optimizer

  ratio = min(2/3., num_frame/max_frame)
  lr = init_lr*(1 - ratio)**power
  for param_group in optimizer.param_groups:
    param_group['lr'] = lr
  
  return lr

# %% [markdown]
# # Env Utils

# %%
from typing import List
import torch
import torch.multiprocessing as mp
import numpy as np
import os.path
import shutil
from PIL import Image, ImageDraw
from collections import deque, defaultdict, namedtuple
import pdb

# device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")

class Counter:
  def __init__(self, init_val: int = 0):
    self._val = mp.RawValue("i", init_val)
    self._lock = mp.Lock()

  def increment(self):
    with self._lock:
      self._val.value += 1

  @property
  def value(self):
    with self._lock:
      return self._val.value

class Timer():
  def __init__(self, maxsize=20):
    self.values = deque(maxlen=maxsize)
    self.count = 0.
    self.sum = 0.

  def update(self, value):
    self.values.append(value)
    self.sum += value
    self.count += 1

  @property
  def avg(self):
    return np.mean(self.values)

  @property
  def global_avg(self):
    return self.sum / self.count

class MetricLogger():
  def __init__(self):
    self.values = defaultdict(Timer)

  def update(self, **kargs):
    for key, value in kargs.items():
      self.values[key].update(value)

  def __getitem__(self, key):
    return self.values[key]

  def __setitem__(self, key, value):
    self.values[key].update(value)

def dec_agent_pos_rot(pos_rot_vec):
  pos = pos_rot_vec[:3]
  rot = pos_rot_vec[3:]
  return pos, rot

def dec_building_pos_scale(pos_scale_vec):
  pos = pos_scale_vec[:27].reshape(9, 3)
  scale = pos_scale_vec[27:54].reshape(9, 3)
  
  return pos, scale

def comp_min_distance_angle(agent_pos, building_pos, building_scale):
  """
  agent_pos: (3,)
  building_pos: (9, 3)
  building_scale: (9, 3)
  
  compute agent and building distance on x-z plane.
  """
  
  num_building = np.sum(np.sum(building_pos, axis=1) != 0)
  
  dis = (agent_pos - building_pos)**2
  dis = np.sqrt(dis[:, 0] + dis[:, 2])
  
  building_radius = (building_scale / 2.)**2
  building_radius = np.sqrt(building_radius[:, 0] + building_radius[:, 2])
  
  dis = dis - building_radius + 5. # distance to the building surface
  
  dis_min_idx = np.argmin(dis[:num_building])
  
  min_building_pos = building_pos[dis_min_idx]
  dis_min = dis[dis_min_idx]
  
  x_offset = min_building_pos[0] - agent_pos[0]
  z_offset = min_building_pos[2] - agent_pos[2]
  cos_theta = x_offset / (np.sqrt(x_offset**2 + z_offset**2) + 1e-5)
  sin_theta = z_offset / (np.sqrt(x_offset**2 + z_offset**2) + 1e-5)
  
  theta = np.degrees(np.arcsin(sin_theta))
  if np.isnan(theta):
    pdb.set_trace()
  if cos_theta < 0.:
    theta = 180. - theta
    
  theta = theta % 360.
  return dis_min, theta

def dec_top_down_map(building_pos_scale_color):
  pos = building_pos_scale_color[:27].reshape(9, 3)
  scale = building_pos_scale_color[27:54].reshape(9, 3)
  color = building_pos_scale_color[54:].reshape(9, 3)
  
  num_building = np.sum(np.sum(pos, axis=1) != 0)

  height = scale[:num_building, 1]
  
  top_down_map = np.zeros((num_building, 64, 64, 3))
  
  for i in range(num_building):
    pos_i_x = (pos[i, 0] + 50) / 100 * 64
    pos_i_z = (pos[i, 2] + 50) / 100 * 64
    
    scale_i_x = scale[i, 0] / 100 * 64
    scale_i_z = scale[i, 2] / 100 * 64
    
    top_down_map[i][64 - int(pos_i_z + scale_i_z // 2) : 64 - int(pos_i_z - scale_i_z // 2 + 1),
                   int(pos_i_x - scale_i_x // 2) : int(pos_i_x + scale_i_x // 2 + 1)] = color[i]
    
  sort_idx = np.argsort(height)
  maps = np.zeros((64, 64, 3))

  for idx in sort_idx:
    
    overlap = (maps > 0.) * (top_down_map[idx] > 0.)
    
    maps = maps * (1. - overlap) + top_down_map[idx]
    
  return maps

def plot_traj(map_top_down, agent_pos):
  """
  agent_pos: T, 2
  """
  
  agent_pos = np.array(agent_pos) + 50
  
  im = Image.fromarray((map_top_down * 255).astype(np.uint8))
  draw = ImageDraw.Draw(im)
  num = agent_pos.shape[0]
  start = agent_pos[0]
  for i in range(1, num):
    end = agent_pos[i]
    draw.line(
      (int(start[0] / 100 * 64), int((100 - start[1]-1) / 100 * 64),
        int(end[0] / 100 * 64), int((100 - end[1]-1) / 100 * 64)),
      fill='red',
      width = 1,
    )
    start = end
    
  return np.asarray(im, dtype='int32')

def plot_traj_step(map_top_down, agent_pos):
  """
  agent_pos: T, 2
  map_top_down: H, W, C
  """
  
  agent_pos = np.array(agent_pos) + 50
  
  im = Image.fromarray((map_top_down * 255).astype(np.uint8))
  draw = ImageDraw.Draw(im)
  num = agent_pos.shape[0]
  start = agent_pos[0]
  map_traj_list = []
  for i in range(num):
    end = agent_pos[i]
    draw.line(
      (int(start[0] / 100 * 64), int((100 - start[1]-1) / 100 * 64),
        int(end[0] / 100 * 64), int((100 - end[1]-1) / 100 * 64)),
      fill='red',
      width = 1,
    )
    start = end
    map_traj_list.append(np.asarray(im, dtype='int32'))

  map_traj = np.array(map_traj_list).astype(np.float) / 255. # B, H, W, C
    
  return map_traj

def agent_building_angle(agent_pos, agent_rot, building_pos, building_scale):
  """
  agent_rot: scalar
  agent_pos: (3,)
  building_pos: (9, 3)
  building_scale: (9, 3)
  
  compute agent and building distance on x-z plane.
  """
  
  num_building = np.sum(np.sum(building_pos, axis=1) != 0)
  
  x_offset = building_pos[:num_building, 0] - agent_pos[0]
  z_offset = building_pos[:num_building, 2] - agent_pos[2]
  cos_theta = x_offset / (np.sqrt(x_offset**2 + z_offset**2) + 1e-5)
  sin_theta = z_offset / (np.sqrt(x_offset**2 + z_offset**2) + 1e-5)
  
  theta = np.degrees(np.arcsin(sin_theta))
  if np.isnan(theta).any():
    pdb.set_trace()
  for i in range(num_building):
    if cos_theta[i] < 0.:
      theta[i] = 180. - theta[i]
    
  theta = theta % 360.
  
  agent_rot_ = (-agent_rot + 90) % 360 # opposite rotation direction, agent facing y+ is 0 rotation
  angle_diff = abs(agent_rot_ - theta)

  return theta, angle_diff

# %% [markdown]
# # Random city dataset

# %%
from torch.utils.data import Dataset
from glob import glob
import gzip
import pickle

class RandomCityDataset(Dataset):
  def __init__(self, split='training'):
    traj_files = sorted(glob('./Datasets/50k/act*'))
    if split == 'training':
      start_idx = 0
      end_idx = 50
    elif split == 'val':
      start_idx = 50
      end_idx = 100
    elif split == 'testing':
      start_idx = 100
      end_idx = 150

    self.traj_files = traj_files[start_idx: end_idx]

  def __len__(self):
    return len(self.traj_files)

  def __getitem__(self, idx):
    traj_file = self.traj_files[idx]

    with gzip.open(traj_file, 'r') as f:
      traj = pickle.load(f)

    agent_view = traj.agent_view
    map_top_down = traj.map_top_down
    actions = traj.a
    pos = traj.pos
    rot = traj.rot

    sample = {
      'agent_view': agent_view,
      'map_top_down': map_top_down,
      'actions': actions,
      'pos': pos,
      'rot': rot
    }
    return sample

# %% [markdown]
# # train_unity_stored_data

# %%
Trajectory = namedtuple(
    "Trajectory",
    [
        "agent_view",
        "map_top_down",
        "a",
        "pos",
        "rot",
    ],
)

# %%
import torch
# from learner_memory import Learner
# from env_utils import *
# from modules_memory import *
# from unity_dataset import RandomCityDataset
from torch.utils.data import DataLoader
# from config import cfg_argparser
# import argparse
import os
import pdb

if __name__ == "__main__":

  log_path = os.path.join(log_path, exp_name + '-lr{}'.format(init_lr))
  if not os.path.exists:
    os.mkdirs(log_path)

  train_ds = RandomCityDataset()
  train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=8)
  print("data_loader length: {}".format(len(train_dl)))

  val_ds = RandomCityDataset(split='val')
  val_dl = DataLoader(val_ds, batch_size=batch_size, shuffle=True, num_workers=8)
  print("data_loader length: {}".format(len(val_dl)))
    
  policy = Policy()
  learner = Learner(1, policy, train_dl, val_dl)
  learner.run()
# Out:
# data_loader length: 5
# data_loader length: 5
# =========== Losses ===========
#
# map_dec_loss:		 971.870300
# position_loss:		 3.231124
# rot_loss:		 3.020029
# kl_loss:		 420.614136
# overshoot_loss:		 829.927979
# model_loss:		 830348.625000
# total_loss:		 831326.750000
# =========== Timer Measure ===========
#
# data_proc_time:		 0.027853
# agent_core_time:		 0.100649
# pos_map_time:		 0.025995
# conv_draw_time:		 0.285321
# backward_time:		 0.463342
# step_time:		 0.062497
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000001.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000002.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000003.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000004.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000005.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000006.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000007.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000008.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000009.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000010.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000011.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000012.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000013.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000014.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000015.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000016.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000017.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000018.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000019.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000020.pth
# =========== Losses ===========
#
# map_dec_loss:		 164.283661
# position_loss:		 2.927176
# rot_loss:		 2.962215
# kl_loss:		 1295.360229
# overshoot_loss:		 180.809189
# model_loss:		 182104.546875
# total_loss:		 182274.718750
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020708
# agent_core_time:		 0.043942
# pos_map_time:		 0.003078
# conv_draw_time:		 0.131211
# backward_time:		 0.477747
# step_time:		 0.020486
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000021.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000022.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000023.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000024.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000025.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000026.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000027.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000028.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000029.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000030.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000031.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000032.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000033.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000034.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000035.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000036.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000037.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000038.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000039.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000040.pth
# =========== Losses ===========
#
# map_dec_loss:		 161.944794
# position_loss:		 2.754492
# rot_loss:		 2.896341
# kl_loss:		 1485.474609
# overshoot_loss:		 100.072243
# model_loss:		 101557.718750
# total_loss:		 101725.320312
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020229
# agent_core_time:		 0.045592
# pos_map_time:		 0.003150
# conv_draw_time:		 0.133138
# backward_time:		 0.480420
# step_time:		 0.021372
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000041.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000042.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000043.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000044.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000045.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000046.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000047.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000048.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000049.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000050.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000051.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000052.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000053.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000054.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000055.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000056.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000057.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000058.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000059.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000060.pth
# =========== Losses ===========
#
# map_dec_loss:		 181.363220
# position_loss:		 2.716399
# rot_loss:		 2.954719
# kl_loss:		 1555.620728
# overshoot_loss:		 56.015743
# model_loss:		 57571.363281
# total_loss:		 57758.394531
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019716
# agent_core_time:		 0.044544
# pos_map_time:		 0.003018
# conv_draw_time:		 0.131515
# backward_time:		 0.481531
# step_time:		 0.021028
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000061.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000062.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000063.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000064.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000065.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000066.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000067.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000068.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000069.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000070.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000071.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000072.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000073.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000074.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000075.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000076.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000077.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000078.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000079.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000080.pth
# =========== Losses ===========
#
# map_dec_loss:		 194.849136
# position_loss:		 2.680770
# rot_loss:		 2.906957
# kl_loss:		 1623.413940
# overshoot_loss:		 56.954033
# model_loss:		 58577.445312
# total_loss:		 58777.878906
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020006
# agent_core_time:		 0.045753
# pos_map_time:		 0.003130
# conv_draw_time:		 0.132469
# backward_time:		 0.483119
# step_time:		 0.021716
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000081.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000082.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000083.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000084.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000085.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000086.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000087.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000088.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000089.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000090.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000091.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000092.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000093.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000094.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000095.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000096.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000097.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000098.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000099.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000100.pth
# =========== Losses ===========
#
# map_dec_loss:		 176.327835
# position_loss:		 2.907960
# rot_loss:		 2.910435
# kl_loss:		 1600.657349
# overshoot_loss:		 55.585381
# model_loss:		 57186.035156
# total_loss:		 57368.179688
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020743
# agent_core_time:		 0.045454
# pos_map_time:		 0.003156
# conv_draw_time:		 0.132234
# backward_time:		 0.484156
# step_time:		 0.022806
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000101.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000102.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000103.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000104.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000105.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000106.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000107.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000108.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000109.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000110.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000111.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000112.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000113.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000114.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000115.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000116.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000117.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000118.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000119.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000120.pth
# =========== Losses ===========
#
# map_dec_loss:		 163.206940
# position_loss:		 2.645373
# rot_loss:		 2.881153
# kl_loss:		 1356.856323
# overshoot_loss:		 37.825569
# model_loss:		 39182.425781
# total_loss:		 39351.160156
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019693
# agent_core_time:		 0.044312
# pos_map_time:		 0.003058
# conv_draw_time:		 0.134288
# backward_time:		 0.477689
# step_time:		 0.019688
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000121.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000122.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000123.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000124.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000125.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000126.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000127.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000128.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000129.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000130.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000131.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000132.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000133.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000134.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000135.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000136.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000137.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000138.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000139.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000140.pth
# =========== Losses ===========
#
# map_dec_loss:		 157.970764
# position_loss:		 2.560523
# rot_loss:		 2.843122
# kl_loss:		 1707.746704
# overshoot_loss:		 40.854836
# model_loss:		 42562.582031
# total_loss:		 42725.957031
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020753
# agent_core_time:		 0.045543
# pos_map_time:		 0.003089
# conv_draw_time:		 0.130832
# backward_time:		 0.485540
# step_time:		 0.021205
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000141.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000142.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000143.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000144.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000145.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000146.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000147.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000148.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000149.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000150.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000151.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000152.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000153.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000154.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000155.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000156.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000157.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000158.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000159.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000160.pth
# =========== Losses ===========
#
# map_dec_loss:		 163.570480
# position_loss:		 2.331372
# rot_loss:		 2.714780
# kl_loss:		 1789.532349
# overshoot_loss:		 48.811096
# model_loss:		 50600.628906
# total_loss:		 50769.246094
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020527
# agent_core_time:		 0.046433
# pos_map_time:		 0.003154
# conv_draw_time:		 0.131887
# backward_time:		 0.482684
# step_time:		 0.021071
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000161.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000162.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000163.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000164.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000165.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000166.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000167.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000168.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000169.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000170.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000171.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000172.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000173.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000174.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000175.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000176.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000177.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000178.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000179.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000180.pth
# =========== Losses ===========
#
# map_dec_loss:		 164.383682
# position_loss:		 2.490850
# rot_loss:		 2.685763
# kl_loss:		 1446.733643
# overshoot_loss:		 23.430670
# model_loss:		 24877.404297
# total_loss:		 25046.962891
# =========== Timer Measure ===========
#
# data_proc_time:		 0.021409
# agent_core_time:		 0.045663
# pos_map_time:		 0.003263
# conv_draw_time:		 0.131085
# backward_time:		 0.481713
# step_time:		 0.021338
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000181.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000182.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000183.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000184.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000185.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000186.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000187.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000188.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000189.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000190.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000191.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000192.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000193.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000194.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000195.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000196.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000197.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000198.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000199.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000200.pth
# =========== Losses ===========
#
# map_dec_loss:		 168.291702
# position_loss:		 2.122189
# rot_loss:		 2.735327
# kl_loss:		 1316.609863
# overshoot_loss:		 15.251392
# model_loss:		 16568.001953
# total_loss:		 16741.150391
# =========== Timer Measure ===========
#
# data_proc_time:		 0.021409
# agent_core_time:		 0.046566
# pos_map_time:		 0.003276
# conv_draw_time:		 0.131927
# backward_time:		 0.480043
# step_time:		 0.022602
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000201.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000202.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000203.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000204.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000205.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000206.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000207.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000208.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000209.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000210.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000211.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000212.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000213.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000214.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000215.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000216.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000217.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000218.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000219.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000220.pth
# =========== Losses ===========
#
# map_dec_loss:		 171.812103
# position_loss:		 2.337290
# rot_loss:		 2.486256
# kl_loss:		 1206.955566
# overshoot_loss:		 14.750800
# model_loss:		 15957.755859
# total_loss:		 16134.391602
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019886
# agent_core_time:		 0.045133
# pos_map_time:		 0.003093
# conv_draw_time:		 0.133291
# backward_time:		 0.483095
# step_time:		 0.020698
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000221.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000222.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000223.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000224.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000225.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000226.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000227.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000228.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000229.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000230.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000231.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000232.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000233.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000234.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000235.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000236.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000237.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000238.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000239.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000240.pth
# =========== Losses ===========
#
# map_dec_loss:		 176.576172
# position_loss:		 1.990951
# rot_loss:		 2.484157
# kl_loss:		 1074.455688
# overshoot_loss:		 16.244194
# model_loss:		 17318.650391
# total_loss:		 17499.701172
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020435
# agent_core_time:		 0.045338
# pos_map_time:		 0.003074
# conv_draw_time:		 0.131486
# backward_time:		 0.481518
# step_time:		 0.021606
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000241.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000242.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000243.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000244.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000245.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000246.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000247.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000248.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000249.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000250.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000251.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000252.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000253.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000254.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000255.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000256.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000257.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000258.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000259.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000260.pth
# =========== Losses ===========
#
# map_dec_loss:		 142.182892
# position_loss:		 2.141816
# rot_loss:		 2.390262
# kl_loss:		 1043.225342
# overshoot_loss:		 8.873926
# model_loss:		 9917.151367
# total_loss:		 10063.866211
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019986
# agent_core_time:		 0.045556
# pos_map_time:		 0.003118
# conv_draw_time:		 0.132528
# backward_time:		 0.484600
# step_time:		 0.021617
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000261.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000262.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000263.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000264.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000265.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000266.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000267.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000268.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000269.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000270.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000271.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000272.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000273.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000274.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000275.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000276.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000277.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000278.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000279.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000280.pth
# =========== Losses ===========
#
# map_dec_loss:		 128.262268
# position_loss:		 2.155519
# rot_loss:		 2.359056
# kl_loss:		 1129.895630
# overshoot_loss:		 13.312765
# model_loss:		 14442.660156
# total_loss:		 14575.437500
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020278
# agent_core_time:		 0.046138
# pos_map_time:		 0.003298
# conv_draw_time:		 0.131290
# backward_time:		 0.479063
# step_time:		 0.021150
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000281.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000282.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000283.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000284.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000285.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000286.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000287.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000288.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000289.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000290.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000291.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000292.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000293.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000294.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000295.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000296.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000297.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000298.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000299.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000300.pth
# =========== Losses ===========
#
# map_dec_loss:		 99.872971
# position_loss:		 1.973366
# rot_loss:		 2.091529
# kl_loss:		 1398.955811
# overshoot_loss:		 17.168694
# model_loss:		 18567.648438
# total_loss:		 18671.585938
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020358
# agent_core_time:		 0.045381
# pos_map_time:		 0.003098
# conv_draw_time:		 0.132638
# backward_time:		 0.482669
# step_time:		 0.021981
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000301.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000302.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000303.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000304.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000305.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000306.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000307.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000308.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000309.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000310.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000311.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000312.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000313.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000314.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000315.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000316.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000317.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000318.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000319.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000320.pth
# =========== Losses ===========
#
# map_dec_loss:		 91.921455
# position_loss:		 2.060347
# rot_loss:		 2.060004
# kl_loss:		 1287.978760
# overshoot_loss:		 12.556452
# model_loss:		 13844.430664
# total_loss:		 13940.472656
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019246
# agent_core_time:		 0.044788
# pos_map_time:		 0.003046
# conv_draw_time:		 0.130303
# backward_time:		 0.483164
# step_time:		 0.020810
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000321.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000322.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000323.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000324.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000325.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000326.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000327.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000328.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000329.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000330.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000331.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000332.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000333.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000334.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000335.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000336.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000337.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000338.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000339.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000340.pth
# =========== Losses ===========
#
# map_dec_loss:		 91.804138
# position_loss:		 1.937632
# rot_loss:		 2.114887
# kl_loss:		 1138.028564
# overshoot_loss:		 10.389091
# model_loss:		 11527.119141
# total_loss:		 11622.975586
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019607
# agent_core_time:		 0.045240
# pos_map_time:		 0.003032
# conv_draw_time:		 0.131107
# backward_time:		 0.478661
# step_time:		 0.021238
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000341.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000342.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000343.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000344.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000345.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000346.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000347.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000348.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000349.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000350.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000351.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000352.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000353.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000354.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000355.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000356.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000357.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000358.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000359.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000360.pth
# =========== Losses ===========
#
# map_dec_loss:		 83.421837
# position_loss:		 1.919315
# rot_loss:		 2.258483
# kl_loss:		 1159.153687
# overshoot_loss:		 11.660733
# model_loss:		 12819.886719
# total_loss:		 12907.486328
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019840
# agent_core_time:		 0.045072
# pos_map_time:		 0.003086
# conv_draw_time:		 0.132299
# backward_time:		 0.484500
# step_time:		 0.022494
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000361.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000362.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000363.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000364.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000365.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000366.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000367.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000368.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000369.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000370.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000371.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000372.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000373.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000374.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000375.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000376.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000377.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000378.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000379.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000380.pth
# =========== Losses ===========
#
# map_dec_loss:		 66.979912
# position_loss:		 1.809620
# rot_loss:		 2.012068
# kl_loss:		 1087.448242
# overshoot_loss:		 10.215633
# model_loss:		 11303.082031
# total_loss:		 11373.882812
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019120
# agent_core_time:		 0.044775
# pos_map_time:		 0.003094
# conv_draw_time:		 0.132149
# backward_time:		 0.483327
# step_time:		 0.020424
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000381.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000382.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000383.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000384.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000385.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000386.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000387.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000388.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000389.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000390.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000391.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000392.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000393.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000394.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000395.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000396.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000397.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000398.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000399.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000400.pth
# =========== Losses ===========
#
# map_dec_loss:		 54.648228
# position_loss:		 1.693936
# rot_loss:		 1.921786
# kl_loss:		 1221.619385
# overshoot_loss:		 8.318700
# model_loss:		 9540.319336
# total_loss:		 9598.583984
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020528
# agent_core_time:		 0.045503
# pos_map_time:		 0.003116
# conv_draw_time:		 0.133215
# backward_time:		 0.481296
# step_time:		 0.023015
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000401.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000402.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000403.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000404.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000405.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000406.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000407.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000408.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000409.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000410.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000411.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000412.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000413.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000414.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/best_model.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000415.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000416.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000417.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000418.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000419.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000420.pth
# =========== Losses ===========
#
# map_dec_loss:		 47.098587
# position_loss:		 1.618428
# rot_loss:		 1.769900
# kl_loss:		 958.329285
# overshoot_loss:		 5.559038
# model_loss:		 6517.367188
# total_loss:		 6567.854492
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019822
# agent_core_time:		 0.044907
# pos_map_time:		 0.003118
# conv_draw_time:		 0.132739
# backward_time:		 0.484752
# step_time:		 0.021301
# ...
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000839.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000840.pth
# =========== Losses ===========
#
# map_dec_loss:		 6.940235
# position_loss:		 0.726287
# rot_loss:		 1.041675
# kl_loss:		 869.974365
# overshoot_loss:		 6.369947
# model_loss:		 7239.921875
# total_loss:		 7248.629883
# =========== Timer Measure ===========
#
# data_proc_time:		 0.022311
# agent_core_time:		 0.048214
# pos_map_time:		 0.003518
# conv_draw_time:		 0.133458
# backward_time:		 0.482374
# step_time:		 0.022922
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000841.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000842.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000843.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000844.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000845.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000846.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000847.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000848.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000849.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000850.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000851.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000852.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000853.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000854.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000855.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000856.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000857.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000858.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000859.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000860.pth
# =========== Losses ===========
#
# map_dec_loss:		 6.554837
# position_loss:		 0.572361
# rot_loss:		 1.151451
# kl_loss:		 666.950623
# overshoot_loss:		 -1.926270
# model_loss:		 -1259.319092
# total_loss:		 -1251.040405
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020759
# agent_core_time:		 0.046084
# pos_map_time:		 0.003274
# conv_draw_time:		 0.132175
# backward_time:		 0.481922
# step_time:		 0.021853
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000861.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000862.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000863.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000864.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000865.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000866.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000867.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000868.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000869.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000870.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000871.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000872.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000873.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000874.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000875.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000876.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000877.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000878.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000879.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000880.pth
# =========== Losses ===========
#
# map_dec_loss:		 5.287951
# position_loss:		 0.655392
# rot_loss:		 1.030094
# kl_loss:		 701.730774
# overshoot_loss:		 -1.246965
# model_loss:		 -545.234558
# total_loss:		 -538.261108
# =========== Timer Measure ===========
#
# data_proc_time:		 0.022725
# agent_core_time:		 0.044534
# pos_map_time:		 0.003061
# conv_draw_time:		 0.131518
# backward_time:		 0.480095
# step_time:		 0.021117
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000881.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000882.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000883.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000884.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000885.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000886.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000887.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000888.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000889.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000890.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000891.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000892.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000893.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000894.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000895.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000896.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000897.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000898.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000899.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000900.pth
# =========== Losses ===========
#
# map_dec_loss:		 5.411549
# position_loss:		 0.617218
# rot_loss:		 1.109767
# kl_loss:		 872.464905
# overshoot_loss:		 2.137775
# model_loss:		 3010.239502
# total_loss:		 3017.378174
# =========== Timer Measure ===========
#
# data_proc_time:		 0.021723
# agent_core_time:		 0.045148
# pos_map_time:		 0.003144
# conv_draw_time:		 0.133013
# backward_time:		 0.482149
# step_time:		 0.022133
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000901.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000902.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000903.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000904.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000905.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000906.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000907.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000908.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000909.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000910.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000911.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000912.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000913.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000914.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000915.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000916.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000917.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000918.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000919.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000920.pth
# =========== Losses ===========
#
# map_dec_loss:		 6.967198
# position_loss:		 0.569892
# rot_loss:		 1.040099
# kl_loss:		 743.078430
# overshoot_loss:		 1.905427
# model_loss:		 2648.505615
# total_loss:		 2657.082764
# =========== Timer Measure ===========
#
# data_proc_time:		 0.022655
# agent_core_time:		 0.045137
# pos_map_time:		 0.003124
# conv_draw_time:		 0.132657
# backward_time:		 0.483312
# step_time:		 0.021104
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000921.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000922.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000923.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000924.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000925.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000926.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000927.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000928.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000929.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000930.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000931.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000932.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000933.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000934.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000935.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000936.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000937.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000938.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000939.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000940.pth
# =========== Losses ===========
#
# map_dec_loss:		 5.789787
# position_loss:		 0.703499
# rot_loss:		 1.006852
# kl_loss:		 758.268005
# overshoot_loss:		 2.438158
# model_loss:		 3196.426270
# total_loss:		 3203.926514
# =========== Timer Measure ===========
#
# data_proc_time:		 0.019447
# agent_core_time:		 0.045314
# pos_map_time:		 0.003136
# conv_draw_time:		 0.132933
# backward_time:		 0.480214
# step_time:		 0.021715
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000941.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000942.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000943.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000944.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000945.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000946.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000947.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000948.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000949.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000950.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000951.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000952.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000953.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000954.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000955.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000956.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000957.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000958.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000959.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000960.pth
# =========== Losses ===========
#
# map_dec_loss:		 4.199004
# position_loss:		 0.462950
# rot_loss:		 0.929739
# kl_loss:		 650.291931
# overshoot_loss:		 -1.933617
# model_loss:		 -1283.324951
# total_loss:		 -1277.733398
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020990
# agent_core_time:		 0.045339
# pos_map_time:		 0.003097
# conv_draw_time:		 0.135047
# backward_time:		 0.481474
# step_time:		 0.021053
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000961.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000962.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000963.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000964.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000965.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000966.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000967.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000968.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000969.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000970.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000971.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000972.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000973.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000974.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000975.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000976.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000977.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000978.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000979.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000980.pth
# =========== Losses ===========
#
# map_dec_loss:		 4.873543
# position_loss:		 0.530392
# rot_loss:		 0.989759
# kl_loss:		 889.858643
# overshoot_loss:		 1.725189
# model_loss:		 2615.047363
# total_loss:		 2621.440918
# =========== Timer Measure ===========
#
# data_proc_time:		 0.020772
# agent_core_time:		 0.046299
# pos_map_time:		 0.003239
# conv_draw_time:		 0.133529
# backward_time:		 0.482236
# step_time:		 0.022010
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000981.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000982.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000983.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000984.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000985.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000986.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000987.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000988.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000989.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000990.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000991.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000992.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000993.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000994.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000995.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000996.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000997.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000998.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000000999.pth
# save model to ./log/unity/mem/50k/exp-lr0.0002/model_saved/model_000001000.pth

# %%
env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-1baceacf4cb1> in <module>
# ----> 1 env.close()
#
# AttributeError: 'str' object has no attribute 'close'

# %%
display.stop()
# Out:
# $DISPLAY was already unset.

# %% [markdown]
# # Config file

# %%
env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-1baceacf4cb1> in <module>
# ----> 1 env.close()
#
# AttributeError: 'str' object has no attribute 'close'

# %%
display.stop()
# Out:
# $DISPLAY was already unset.

# %%
import pickle
import gzip


# with open('./Datasets/50k/actor-26-traj-1.pkl', 'rb') as f:
#     data = pickle.load()

import pickle

# import class_def
# from class_def import Foo # Import Foo into main_module's namespace explicitly

if __name__=='__main__':
    with gzip.open('./Datasets/50k/actor-26-traj-1.pkl', 'r') as f:
          traj = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-8ee4978211ec> in <module>
#      13 if __name__=='__main__':
#      14     with gzip.open('./Datasets/50k/actor-26-traj-1.pkl', 'r') as f:
# ---> 15           traj = pickle.load(f)
#
# AttributeError: Can't get attribute 'Trajectory' on <module '__main__'>
